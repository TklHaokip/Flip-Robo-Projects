# %% [markdown]
# ## **E-retail factors for customer activation and retention: A case study from Indian e-commerce customers**
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
#
# **Be careful: There are two sheets (one is detailed) and second is encoded in the excel file. You may use any of them by extracting in separate excel sheet. The number of column(s) is more than 47. Read the column header carefully.**
#
# **Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.**
# Need not to create machine learning models /but still if anybody comes with it that is welcome.
#
# ![CR.jpg](data:image/jpeg;base64,...)
#
#
#
#
#
# **Disclaimer:  The datasets and figure(s) are highly confidential. Any kind of commercial activities find with the content will be taken strict action. The dataset is only available for academic purpose. **

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Importing Required Libraries**

# %%
# Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Load Data**

# %%
#  Read Data
df = pd.read_excel('/content/drive/MyDrive/Customer_retention_dataset/customer_retention_dataset.xlsx')
df.head()
# Out:
#   1Gender of respondent  ... Which of the Indian online retailer would you recommend to a friend?
# 0                  Male  ...                                       Flipkart.com
# 1                Female  ...                              Amazon.in, Myntra.com
# 2                Female  ...                   Amazon.in, Paytm.com, Myntra.com
# 3                  Male  ...                            Amazon.in, Flipkart.com
# 4                Female  ...                              Amazon.in, Myntra.com
#
# [5 rows x 71 columns]

# %%
# Tail
df.tail()
# Out:
#     1Gender of respondent  ... Which of the Indian online retailer would you recommend to a friend?
# 264                Female  ...                                          Amazon.in
# 265                Female  ...                                       Flipkart.com
# 266                Female  ...                                          Amazon.in
# 267                Female  ...                                          Amazon.in
# 268                Female  ...                                          Amazon.in
#
# [5 rows x 71 columns]

# %% [markdown]
# # **Data Analysis**

# %%
# Shape(rows,columns)
df.shape
# Out:
# (269, 71)

# %%
# DataTypes
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
# Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
# Missing Values
plt.figure(figsize=(12,7))
sns.heatmap(df.isna(),yticklabels=False)

# %%
# Confirmation
df.isna().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
# Duplicated Entries
df.duplicated().sum()
# Out:
# 166

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)
# Confirm
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.columns
# I just leave the Features as it is instead of assigning new names. So, that no confusion is created.
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# Visualizing the count of gender
plt.figure(figsize=(10,7))
sns.countplot(data=df,x='1Gender of respondent')

# %%
# Number Gender counts
print(df['1Gender of respondent'].value_counts())
# Out:
# Female    66
# Male      37
# Name: 1Gender of respondent, dtype: int64

# %%
# city from where you shop online from based on gender
plt.figure(figsize=(10,7))
plt.xticks(rotation=50)
sns.countplot(data=df,hue='1Gender of respondent',x='3 Which city do you shop online from?')

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=50)
sns.countplot(data=df,hue='1Gender of respondent',x='5 Since How Long You are Shopping Online ?')

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=50)
sns.countplot(data=df,hue='1Gender of respondent',x='6 How many times you have made an online purchase in the past 1 year?')

# %%
# Number of city count
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            22
# Greater Noida    17
# Noida            17
# Bangalore        17
# Karnal           11
# Merrut            5
# Ghaziabad         5
# Solan             4
# Gurgaon           3
# Moradabad         1
# Bulandshahr       1
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
# Which city do you shop online from and for how many years?
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='3 Which city do you shop online from?',hue='5 Since How Long You are Shopping Online ?')

# %%
# Which city do you shop online from and for how many years?
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='3 Which city do you shop online from?',hue='6 How many times you have made an online purchase in the past 1 year?')

# %%
# city from where you shop online from based on internet access made
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='3 Which city do you shop online from?',hue='7 How do you access the internet while shopping on-line?')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='8 Which device do you use to access the online shopping?')

# %%
# City of shoping based on Devices used
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='3 Which city do you shop online from?',hue='8 Which device do you use to access the online shopping?')

# %%
# Number of years shopping online
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='5 Since How Long You are Shopping Online ?')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='6 How many times you have made an online purchase in the past 1 year?')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='6 How many times you have made an online purchase in the past 1 year?',hue='5 Since How Long You are Shopping Online ?')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='1Gender of respondent',hue='7 How do you access the internet while shopping on-line?')

# %%
# Openions on easy to read website content & understand
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='18 The content on the website must be easy to read and understand')

# %%
# Customers openion on content on the website must be easy to read and understand based on Gender of respondent
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,hue='18 The content on the website must be easy to read and understand',x='1Gender of respondent')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='20 Complete information on listed seller and product being offered is important for purchase decision.')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,hue='20 Complete information on listed seller and product being offered is important for purchase decision.',x='1Gender of respondent')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='21 All relevant information on listed products must be stated clearly')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='22 Ease of navigation in website')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='23 Loading and processing speed')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='24 User friendly Interface of the website')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='25 Convenient Payment methods')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='27 Empathy (readiness to assist with queries) towards the customers')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='28 Being able to guarantee the privacy of the customer')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='30 Online shopping gives monetary benefit and discounts')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='31 Enjoyment is derived from shopping online')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='32 Shopping online is convenient and flexible')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='33 Return and replacement policy of the e-tailer is important for purchase decision')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='34 Gaining access to loyalty programs is a benefit of shopping online')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='35 Displaying quality Information on the website improves satisfaction of customers')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='36 User derive satisfaction while shopping on a good quality website or application')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='37 Net Benefit derived from shopping online can lead to users satisfaction')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='38 User satisfaction cannot exist without trust')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='39 Offering a wide variety of listed product in several category')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='40 Provision of complete and relevant product information')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='41 Monetary savings')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='42 The Convenience of patronizing the online retailer')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='43 Shopping on the website gives you the sense of adventure')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='44 Shopping on your preferred e-tailer enhances your social status')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='45 You feel gratification shopping on your favorite e-tailer')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='46 Shopping on the website helps you fulfill certain roles')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data=df,x='47 Getting value for money spent')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Easy to use website or application')

# %% [markdown]
# # **Visual Inferences**
# - More female shop online than male
# - There are 11 different cities from where customers shop online from.
# - most customers made purchase less than 10 times in the past 1 year
# - There are four different devices used to access the online shopping
# - Means of accessing the internet is mostly from mobile internet
# - most people preferred The content on the website must be easy to read and understand
# - Complete information on listed seller and product being offered is important for purchase decision
# - There is high chanceses of purchase if all relevant information on listed products must be stated clearly
# - Fast processing speed and user friendly of the website is needed
# - Gaining access to loyalty programs is a benefit of shopping online & User derive satisfaction while shopping on a good quality website or application
# - Shopping on the website gives you the sense of adventure
# - Amazon,myntra,flipkart, and Snapdeal are some of the most easy to use application preferred by people.

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Visual appealing web-page layout')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Wild variety of product on offer')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Complete, relevant description information of products')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Fast loading website speed of website and application')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Reliability of the website or application')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Quickness to complete purchase')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Availability of several payment options')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Privacy of customers’ information')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Security of customer financial information')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Perceived Trustworthiness')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Presence of online assistance through multi-channel')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Longer time to get logged in (promotion, sales period)')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Longer time in displaying graphics and photos (promotion, sales period)')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Late declaration of price (promotion, sales period)')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Longer page loading time (promotion, sales period)')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Limited mode of payment on most products (promotion, sales period)')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Longer delivery period')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Change in website/Application design')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Frequent disruption when moving from one page to another')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Website is as efficient as before')

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=90)
sns.countplot(data=df,x='Which of the Indian online retailer would you recommend to a friend?')

# %% [markdown]
# # **Visual Inferences**
# - Amazon & flipkart have a visually appealing web-page layout with wild variety of products are being offered with complete relevant information about the products.
# - Paytm and Amazon has fast loading website or application
# - paytm,flipkart,myntra & amazon are some of the reliable website or application with availability of several payment options.
# - High security and protecting the privacy of the customer is very important to customer
# - Snapdeal has limited mode of payment & paytm takes longer period for delivery
# - Amazon is the most likely recommended online shopping apps to a friend.
